# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# import cv2
# from google.colab.patches import cv2_imshow

# # Load the images
# background = cv2.imread('person.jpeg')
# overlay = cv2.imread('sunn.png')

# # Resize the overlay image to match the dimensions of the background image
# overlay = cv2.resize(overlay, (background.shape[1], background.shape[0]))

# # Perform alpha blending
# alpha = 0.1  # Alpha value for blending (0.0 for completely transparent, 1.0 for completely opaque)
# blended = cv2.addWeighted(background, 1 - alpha, overlay, alpha, 0)

# # Display the result
# cv2_imshow(blended)
# cv2.waitKey(0)
# cv2.destroyAllWindows()



# import cv2
# from google.colab.patches import cv2_imshow
# # Load the main image and the logo image
# main_image = cv2.imread('person.jpeg')
# logo = cv2.imread('gg.png')

# # Define the position to place the logo on the main image (top left corner)
# x_offset = 60  # X-coordinate of the top left corner
# y_offset = 50  # Y-coordinate of the top left corner

# # Resize the logo image to fit within the specified region of the main image
# logo_resized = cv2.resize(logo, (90, 60))

# # Overlay the resized logo image onto the main image at the specified position
# main_image[y_offset:y_offset+logo_resized.shape[0], x_offset:x_offset+logo_resized.shape[1]] = logo_resized
# # Display the resulting image
# cv2_imshow( main_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

from PIL import Image
from IPython.display import display

# Open the main image and the logo image with transparency
main_image = Image.open('person.jpeg').convert('RGBA')
logo = Image.open('img.jpg').convert('RGBA')

# Define the position to place the logo on the main image (top left corner)
x_offset = 60  # X-coordinate of the top left corner
y_offset = 50  # Y-coordinate of the top left corner

# Resize the logo image to fit within the specified region of the main image
logo_resized = logo.resize((80, 90))

# Convert white color to transparent in the logo image
logo_alpha = logo_resized.convert('RGBA')
data = logo_alpha.getdata()

# Replace white color with transparent pixels
new_data = []
for item in data:
    if item[:3] == (255, 255, 255):
        new_data.append((255, 255, 255, 0))
    else:
        new_data.append(item)

logo_alpha.putdata(new_data)

# Paste the logo onto the main image at the specified position
main_image.paste(logo_alpha, (x_offset, y_offset), logo_alpha)

# Display the resulting image
display(main_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=194x259>

# %%
img.shape
# Out:
# (772, 580, 3)

# %%
img1 = img.copy()
cascade_path = '/content/frontalEyes35x16.xml'
eye_cascade = cv2.CascadeClassifier(cascade_path)
eye = eye_cascade.detectMultiScale(img)
eye
# Out:
# array([[172, 251, 247, 113]], dtype=int32)

# %%
eye_x, eye_y, eye_w, eye_h = eye[0]
eye_x, eye_y, eye_w, eye_h
# Out:
# (172, 251, 247, 113)

# %%
img = cv2.rectangle(img, (eye_x, eye_y), (eye_x + eye_w, eye_y + eye_h), (0,255,255), 2)
plt.imshow(img)
plt.show()

# %%
glasses_filter =plt.imread("/content/filter.png")

plt.imshow(glasses_filter)
plt.show
glasses_filter.shape
# Out:
# (360, 360, 3)

# %%
glasses_filter_updated = cv2.resize(glasses_filter,(eye_w+50,eye_h+55))

plt.imshow(glasses_filter_updated)
plt.show
glasses_filter_updated.shape
# Out:
# (168, 297, 3)

# %%
import cv2
from matplotlib import pyplot as plt

# Load the image
image = cv2.imread('ii2.jpg')

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to smooth the image
blurred = cv2.GaussianBlur(gray, (15, 15), 0)

# Apply adaptive thresholding to obtain a binary mask of the blemishes
mask = cv2.adaptiveThreshold(blurred, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV,111, 10)

# Inpaint the blemishes using the mask
inpainted_image = cv2.inpaint(image, mask, 3, cv2.INPAINT_TELEA)

# Display the original image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()

# Display the inpainted image
plt.imshow(cv2.cvtColor(inpainted_image, cv2.COLOR_BGR2RGB))
plt.title('Inpainted Image')
plt.axis('off')
plt.show()

# %%
# !pip install opencv-python
# !pip install cvzone

# %%
# !pip install mediapipe

# %%
import cv2
from google.colab.patches import cv2_imshow
from cvzone.SelfiSegmentationModule import SelfiSegmentation
green_screen_img = cv2.imread("fg.jpg")
bg_img = cv2.imread("bg.jpg")

# %%
w, h = 640, 480
green_screen_img = cv2.resize(green_screen_img, (w, h))
bg_img = cv2.resize(bg_img, (w, h))
segmentor = SelfiSegmentation()
output = segmentor.removeBG(green_screen_img, bg_img)
cv2_imshow(output)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
# -1

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

query_img = cv2.imread('iron.jpg')
train_img = cv2.imread('iron1.jpeg')

query_img_bw = cv2.cvtColor(query_img,cv2.COLOR_BGR2GRAY)
train_img_bw = cv2.cvtColor(train_img, cv2.COLOR_BGR2GRAY)

orb = cv2.ORB_create()

queryKeypoints, queryDescriptors = orb.detectAndCompute(query_img_bw,None)
trainKeypoints, trainDescriptors = orb.detectAndCompute(train_img_bw,None)

matcher = cv2.BFMatcher()
matches = matcher.match(queryDescriptors,trainDescriptors)

final_img = cv2.drawMatches(query_img, queryKeypoints,
train_img, trainKeypoints, matches[:100],None)
final_img = cv2.resize(final_img, (1000,650))
cv2_imshow(final_img)
cv2.waitKey(3000)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x650>
# -1

# %%
import cv2
from google.colab.patches
import cv2_imshow import numpy as np
# Load the image
img = cv2.imread("coin.jpg")
 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5, 5), 0)
ret, thresh = cv2.threshold(blur, 0, 255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE,
cv2.CHAIN_APPROX_SIMPLE)
cv2.drawContours(img, contours, -1, (0, 0, 255), 2)
for cnt in contours:
  area = cv2.contourArea(cnt)
  if area < 1000:
    cv2.drawContours(thresh, [cnt], 0, (0,0,0), -1)
cv2_imshow(thresh)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %%
# Out:
# <PIL.Image.Image image mode=RGBA size=540x360>
